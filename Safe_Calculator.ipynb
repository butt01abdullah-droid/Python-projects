# %% [markdown]
# <a href="https://colab.research.google.com/github/butt01abdullah-droid/Python-projects/blob/main/Safe_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num=int(input("enter a number"))
  result=10/num
  print("results:",result)
except ZeroDivisionError:
  print("Error, cannot divide by zero")
except ValueError:
  print("Error, invalid input enter a valid number")
# Out:
# enter a number#
# Error, invalid input enter a valid number

# %%
def withdraw(amount):
  if amount<0:
    raise ValueError("invalid withdrawal amount")
    print(f"you have withdraw ${amount}")
try:
  withdraw(-50)
except ValueError as e:
  print(e)
# Out:
# invalid withdrawal amount

# %%
#Safe calculator

# Step 1: Define Simple calculator
def add(x,y):
  return x+y
def subtract(x,y):
  return x-y
def multiply(x,y):
  return x*y
def divide(x,y):
  if y==0:
    raise ZeroDivisionError("cannot divide by zero")
  return x/y

# Step 2: Display Menu
print("-----------Simple Calculator Menu:--------------")
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")
print("5. Exit menu")

# Step 3:Main program
while True:
  try:
    choice=input("Enter your choice(1-5):")
    num1=float(input("Enter first number:"))
    num2=float(input("Enter second number:"))
    if choice=='5':
      print("Exiting the calculator")
      break
    elif choice=='1':
      result=add(num1,num2)
      print("Result:",result)
    elif choice=='2':
      result=subtract(num1,num2)
      print("Result:",result)
    elif choice=='3':
      result=multiply(num1,num2)
      print("Result:",result)
    elif choice=='4':
      result=divide(num1,num2)
      print("Result:",result)
    else:
      print("Invalid choice. Please select a valid option.")
      continue
  except ValueError:
      print("Invalid input. Please enter valid numbers.")
  except ZeroDivisionError as e:
      print(f"Error: {e}")
  except Exception as e:
      print(f"An unexpected error occurred: {e}")
  finally:
      print("Thank you for using the calculator.......Resarting.......")
# Out:
# -----------Simple Calculator Menu:--------------
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit menu
# Result: 79.0
# Thank you for using the calculator.......Resarting.......
# Thank you for using the calculator.......Resarting.......
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1224535358.py in <cell line: 0>()
#      25   try:
#      26     choice=input("Enter your choice(1-5):")
# ---> 27     num1=float(input("Enter first number:"))
#      28     num2=float(input("Enter second number:"))
#      29     if choice=='5':
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...

# %%
# Temperature Converter

# Step 1: Define conversion fuctions
def celsius_to_fahrenheit(celsius):
  return (celsius*9/5)+32
def fahrenheit_to_celsius(fahrenheit):
  return (fahrenheit-32)*5/9
def celsius_to_kelvin(celsius):
  return celsius+273.15
def kelvin_to_celsius(kelvin):
  return kelvin-273.15
def kelvin_to_fahrenheit(kelvin):
  celsius=kelvin_to_celsius(kelvin)
  fahrenheit=celsius_to_fahrenheit(celsius)
  return fahrenheit
def fahrenheit_to_kelvin(fahrenheit):
  celsius=fahrenheit_to_celsius(fahrenheit)
  kelvin=celsius_to_kelvin(celsius)
  return kelvin

# Step 2: Display the Menu
def show_menu():
    print("-------------Temperature Conversion Menu:----------------")
    print("1. Celsius to Fahrenheit")
    print("2. Fahrenheit to Celsius")
    print("3. Celsius to Kelvin")
    print("4. Kelvin to Celsius")
    print("5. Kelvin to Fahrenheit")
    print("6. Fahrenheit to Kelvin")
    print("7. Exit Menu")

# Step 3:Main program
while True:
  show_menu()
  choice=input("Enter your choice(1-7):")
  if choice=='7':
    print("Exiting the temperature converter ---------restarting---------")
    break
  elif choice=='1':
    celsius=float(input("Enter temperature in Celsius:"))
    fahrenheit=celsius_to_fahrenheit(celsius)
    print(f"{celsius} degrees Celsius is equal to {fahrenheit} degrees Fahrenheit")
  elif choice=='2':
    fahrenheit=float(input("Enter temperature in Fahrenheit:"))
    celsius=fahrenheit_to_celsius(fahrenheit)
    print(f"{fahrenheit} degrees Fahrenheit is equal to {celsius} degrees Celsius")
  elif choice=='3':
    celsius=float(input("Enter temperature in Celsius:"))
    kelvin=celsius_to_kelvin(celsius)
    print(f"{celsius} degrees Celsius is equal to {kelvin} degrees Kelvin")
  elif choice=='4':
    kelvin=float(input("Enter temperature in Kelvin:"))
    celsius=kelvin_to_celsius(kelvin)
    print(f"{kelvin} degrees Kelvin is equal to {celsius} degrees Celsius")
  elif choice=='5':
    kelvin=float(input("Enter temperature in Kelvin:"))
    fahrenheit=kelvin_to_fahrenheit(kelvin)
    print(f"{kelvin} degrees Kelvin is equal to {fahrenheit} degrees Fahrenheit")
  elif choice=='6':
    fahrenheit=float(input("Enter temperature in Fahrenheit:"))
    kelvin=fahrenheit_to_kelvin(fahrenheit)
    print(f"{fahrenheit} degrees Fahrenheit is equal to {kelvin} degrees Kelvin")
  else:
    print("Invalid choice. Enter a right choice")
# Out:
# -------------Temperature Conversion Menu:----------------
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# 3. Celsius to Kelvin
# 4. Kelvin to Celsius
# 5. Kelvin to Fahrenheit
# 6. Fahrenheit to Kelvin
# 7. Exit Menu
# Enter your choice(1-7):1
# Enter temperature in Celsius:45
# 45.0 degrees Celsius is equal to 113.0 degrees Fahrenheit
# -------------Temperature Conversion Menu:----------------
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# 3. Celsius to Kelvin
# 4. Kelvin to Celsius
# 5. Kelvin to Fahrenheit
# 6. Fahrenheit to Kelvin
# 7. Exit Menu
# Enter your choice(1-7):7
# Exiting the temperature converter

# %%
square =[x**2 for x in range(1,11)]
print(square)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
number=[1,2,3,4,4,5,5,6,7,8]
unique_number=[x for x in set(number)if x%2==0]
print(unique_number)
# Out:
# [2, 4, 6, 8]

# %%
number=[1,2,3,4,4,5,5,6,7,8]
labels= ["even" if x%2==0 else "odd" for x in number]
print(labels)
# Out:
# ['odd', 'even', 'odd', 'even', 'even', 'odd', 'odd', 'even', 'odd', 'even']

# %%
# Student Grade Mnanger

# Step 1: Get students score
students_scores= input("Enter students scores separated by commas:")
scores= [int(score) for score in students_scores.split(',')]

# Step 2: Calculate and display grade
grades= [
    "A" if score>=90 else
    "B" if score>=80 else
    "C" if score>=70 else
    "D" if score>=60 else
    "F"
    for score in scores
        ]
# Step 3: Filtering passin and failing students
passing_students=[score for score in scores if score>=60]
failing_students=[score for score in scores if score<60]

# Step 4: print results
print("\n ------------Dispalying results of students with grades------------- ")
for i in range(len(scores)):
  print(f"Student {i+1}: Score={scores[i]}, Grade={grades[i]}")
print("----------Passed and Failed students are---------")
print("Passing Students:",passing_students,"\nTotal Passing Students:",len(passing_students))
print("Failing Students:",failing_students,"\nTotal Failing Students:",len(failing_students))
# Out:
# Enter students scores separated by commas:70,30,59,69,89,90
#
#  ------------Dispalying results of students with grades-------------
# Student 1: Score=70, Grade=C
# Student 2: Score=30, Grade=F
# Student 3: Score=59, Grade=F
# Student 4: Score=69, Grade=D
# Student 5: Score=89, Grade=B
# Student 6: Score=90, Grade=A
# ----------Passed and Failed students are---------
# Passing Students: [70, 69, 89, 90]
# Total Passing Students: 4
# Failing Students: [30, 59]
# Total Failing Students: 2
